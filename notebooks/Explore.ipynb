# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # San Diego Homelessness Contract Annotations
# `sdcta.org-hl_contracts-1.1.1` Last Update: 2021-08-12T17:13:27
#
# _Processed TagTog annotations for homelessness contracts collected by the_
#
#
# Processed TagTog annotations for homelessness contracts collected by the
# San Diego County Taxpayers Association.
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [annotations](data/annotations.csv)**. Extractsed and processed annotations.
# * ** [contexts](data/contexts.csv)**. Surrounding paragraphs for the annotations, linked by 'part'
#
# ## References
# <ul><li> <strong>annotations_source</string>, <em>data/homelessness-contracts-20210811.zip</em>. Zip file downloaded from TagTog with text and annotations</li><ul>

# %%
ann = pkg.resource('annotations').dataframe()
ctx = pkg.resource('contexts').dataframe()

# %%
ann.head().T
# Out:
#                                                                  0  \
# classid                                                        e_7
# part                                                          s1v1
# offset_start                                                    33
# text                                           COUNTY OF SAN DIEGO
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.975784
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                                    payor
#
#                                                                  1  \
# classid                                                       e_19
# part                                                          s1v1
# offset_start                                                    33
# text             COUNTY OF SAN DIEGO- DEPARTMENT OF PURCHASINGA...
# coordinates                                                    NaN
# confidence                                               pre-added
# confidence_prob                                                1.0
# fields                                                          {}
# normalizations                                                  {}
# who                                                     user:SDTEF
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                             116.17
# coordinates_0_y                                              42.35
# coordinates_1_x                                             405.62
# coordinates_1_y                                              59.19
# value                                                         <NA>
# anno_type                                                 contract
#
#                                                                  2  \
# classid                                                        e_1
# part                                                          s1v1
# offset_start                                                   127
# text                                    Interfaith Shelter Network
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.813213
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                             organization
#
#                                                                  3  \
# classid                                                        e_6
# part                                                          s1v1
# offset_start                                                   153
# text                                                             .
# coordinates                                                     []
# confidence                                               pre-added
# confidence_prob                                                0.5
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:regex
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                             goal-service
#
#                                                                  4
# classid                                                        e_4
# part                                                          s1v1
# offset_start                                                   340
# text                                              Statement ofWork
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.900681
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                                  service

# %%
t = ann.groupby('part').anno_type.value_counts().to_frame('at_counts').reset_index()
t.part.value_counts()
# Out:
# s9v1      9
# s26v1     9
# s7v1      9
# s1p1      9
# s28v1     9
#          ..
# s1p82     1
# s1p78     1
# s1p108    1
# s1p71     1
# s1p31     1
# Name: part, Length: 272, dtype: int64
